# %% [markdown]
# # 새로 만든 데이터 로드해서 시작하기 아래는 초기 코드

# %% [markdown]
# # 1. 라이브러리 로드

# %%
import pandas as pd
import numpy as np
import re
import os
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.font_manager as fm
import matplotlib as mpl
import gc
import statistics as st
plt.rcParams['font.family'] = 'Malgun Gothic'
rc={'axes.labelsize': 15, 'font.size': 15, 'legend.fontsize': 12.0, 'axes.titlesize': 20}
plt.rcParams.update(**rc)
mpl.rcParams['axes.unicode_minus'] = False
os.getcwd()
# Out:
# 'D:\\kaggle\\ELO'

# %% [markdown]
# # 2. 데이터 로드 및 메모리 최적화
# * train.csv: 학습 데이터
# * test.csv: 테스트 데이터
# * tr_train : transaction(history+new).csv에 train.csv 붙인거
# * tr_test  : transaction(history+new).csv에 test.csv 붙인거

# %% [markdown]
# ### 데이터 로드

# %%
# %%time
train=pd.read_csv("D:/kaggle/ELO/data/new/train.csv",encoding='utf-8')
test=pd.read_csv("D:/kaggle/ELO/data/new/test.csv",encoding='utf-8')

tr_train=pd.read_csv("D:/kaggle/ELO/data/new/tr_train.csv",encoding='utf-8')
tr_test=pd.read_csv("D:/kaggle/ELO/data/new/tr_test.csv",encoding='utf-8')
# Out:
# Wall time: 1min 4s

# %% [markdown]
# ### 메모리 최적화

# %%
def reduce_mem_usage(props, fillna=False):
    start_mem_usg = props.memory_usage().sum() / 1024**2 
    print("Memory usage of properties dataframe is :",start_mem_usg," MB")
    NAlist = [] # Keeps track of columns that have missing values filled in. 
    for col in props.columns:
        if props[col].dtype != object:  # Exclude strings
            # Print current column type
            print("******************************")
            print("Column: ",col)
            print("dtype before: ",props[col].dtype)
            
            # make variables for Int, max and min
            IsInt = False
            mx = props[col].max()
            mn = props[col].min()
            
            
            # Integer does not support NA, therefore, NA needs to be filled
            if not np.isfinite(props[col]).all(): 
                if not fillna:
                    print('[*]skip {} cause of NA value'.format(col))
                    continue
                NAlist.append(col)
                props[col].fillna(mn-1,inplace=True)  
                   
            # test if column can be converted to an integer
            asint = props[col].fillna(0).astype(np.int64)
            result = (props[col] - asint)
            result = result.sum()
            if result > -0.01 and result < 0.01:
                IsInt = True
            # Make Integer/unsigned Integer datatypes
            if IsInt:
                if mn >= 0:
                    if mx < 255:
                        props[col] = props[col].astype(np.uint8)
                    elif mx < 65535:
                        props[col] = props[col].astype(np.uint16)
                    elif mx < 4294967295:
                        props[col] = props[col].astype(np.uint32)
                    else:
                        props[col] = props[col].astype(np.uint64)
                else:
                    if mn > np.iinfo(np.int8).min and mx < np.iinfo(np.int8).max:
                        props[col] = props[col].astype(np.int8)
                    elif mn > np.iinfo(np.int16).min and mx < np.iinfo(np.int16).max:
                        props[col] = props[col].astype(np.int16)
                    elif mn > np.iinfo(np.int32).min and mx < np.iinfo(np.int32).max:
                        props[col] = props[col].astype(np.int32)
                    elif mn > np.iinfo(np.int64).min and mx < np.iinfo(np.int64).max:
                        props[col] = props[col].astype(np.int64)    
            # Make float datatypes 32 bit
            else:
                props[col] = props[col].astype(np.float32)
            
            # Print new column type
            print("dtype after: ",props[col].dtype)
            print("******************************")
    # Print final result
    print("___MEMORY USAGE AFTER COMPLETION:___")
    mem_usg = props.memory_usage().sum() / 1024**2 
    print("Memory usage is: ",mem_usg," MB")
    print("This is ",100*mem_usg/start_mem_usg,"% of the initial size")
    return props, NAlist

# %%
train, _ = reduce_mem_usage(train,fillna=False)
test, _ = reduce_mem_usage(test,fillna=False)
tr_train, _ = reduce_mem_usage(tr_train,fillna=False)
tr_test, _ = reduce_mem_usage(tr_test,fillna=False)
# Out:
# Memory usage of properties dataframe is : 9.243148803710938  MB
# ******************************
# Column:  feature_1
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_2
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_3
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  4.429072380065918  MB
# This is  47.91735450897139 % of the initial size
# Memory usage of properties dataframe is : 5.6591339111328125  MB
# ******************************
# Column:  feature_1
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_2
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_3
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  target
# dtype before:  float64
# [*]skip target cause of NA value
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  3.183316230773926  MB
# This is  56.25094370910032 % of the initial size
# Memory usage of properties dataframe is : 2790.4068145751953  MB
# ******************************
# Column:  city_id
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  installments
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  merchant_category_id
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  month_lag
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  purchase_amount
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  category_2
# dtype before:  float64
# [*]skip category_2 cause of NA value
# ******************************
# Column:  state_id
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  subsector_id
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  feature_1
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_2
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_3
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1542.0669784545898  MB
# This is  55.26315985181359 % of the initial size
# Memory usage of properties dataframe is : 1714.2355194091797  MB
# ******************************
# Column:  city_id
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  installments
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  merchant_category_id
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  month_lag
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  purchase_amount
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  category_2
# dtype before:  float64
# [*]skip category_2 cause of NA value
# ******************************
# Column:  state_id
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  subsector_id
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  feature_1
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_2
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_3
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  target
# dtype before:  float64
# [*]skip target cause of NA value
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  992.4521942138672  MB
# This is  57.894739840411255 % of the initial size

# %% [markdown]
# # 4. base_model 생성
#
# #### 1) train+test(transaction) 통합 df 생성
#
# #### 2) na 처리 / Y/N 데이터 이진화(1/0)
# * category_2 / category_3 / merchant_id / first_active_month 열의 NA값 대체
# * authorized_flag / categoryr_1의 Y/N을 1/0 으로 이진화
#
# #### 3) interval_month 생성
# * interval_month = purchase_date(month) - first_active_month(month)
#
# #### 4) datetime 분리
# * ex) year / month / weekday(0/1) / weekend(0/1)
#
# #### 5) purchase_amount_log1p 생성
# * np.log1p(purchase_amount) , df['purchase_amount_log1p']
#
# #### 6)  id별 nunique(개수) 값 열 생성
# * ex) card_id="C_ID_bd97b86450"의 city_id의 nunique가 3이면 city_id_n=3
#
# #### 7) id별 mean or sum 인 열 생성
# * ex) card_id="C_ID_bd97b86450"의 installments 평균이 1이면 installments_mean=1
#
# #### 8) id별 min_max 인 열 생성
# * ex) card_id="C_ID_bd97b86450"의 purchase_amount 최솟값이 .5444이면 installments_min=.5444

# %%
#train,test card_id 보존
train_id=np.unique(tr_train.card_id)
test_id=np.unique(tr_test.card_id)

# %% [markdown]
# ### 1) train_test 통합 df 생성

# %%
df=pd.concat([tr_train,tr_test],axis=0).reset_index(drop=True)
df.tail()
# Out:
#          authorized_flag          card_id  city_id category_1  installments  \
# 31075387               Y  C_ID_06512aaeca       69          N             0
# 31075388               Y  C_ID_8dedf7350a      174          N             1
# 31075389               Y  C_ID_c07707ff74      194          N             2
# 31075390               Y  C_ID_611d4d588f      302          N             1
# 31075391               Y  C_ID_1320dee851      142          N             0
#
#          category_3  merchant_category_id      merchant_id  month_lag  \
# 31075387          A                   317  M_ID_f3867a48a4          1
# 31075388          B                   222  M_ID_c0915e5912          1
# 31075389          C                    87  M_ID_7dabac675c          1
# 31075390          B                   307  M_ID_ee5a6f6a35          2
# 31075391          A                   309  M_ID_7754b67f3b          2
#
#           purchase_amount        purchase_date  category_2  state_id  \
# 31075387        -0.701828  2018-03-03 12:58:59         1.0         9
# 31075388        -0.710844  2018-03-14 14:56:26         1.0         9
# 31075389        -0.476431  2018-03-29 17:41:22         5.0        21
# 31075390        -0.731881  2018-03-11 15:07:49         3.0         7
# 31075391        -0.701828  2018-04-06 14:36:52         3.0        19
#
#           subsector_id first_active_month  feature_1  feature_2  feature_3  \
# 31075387            25            2017-10          2          2          0
# 31075388            21            2017-06          2          1          0
# 31075389            27            2015-09          5          1          1
# 31075390            19            2017-10          2          2          0
# 31075391            21            2017-08          3          1          1
#
#           target
# 31075387     NaN
# 31075388     NaN
# 31075389     NaN
# 31075390     NaN
# 31075391     NaN

# %% [markdown]
# ### 2) na 처리 / Y/N 데이터 이진화(1/0)

# %%
# NA 확인 및 가장 많은 값으로 채우기
# category_2 / category_3 / merchant_id 에서 존재
# target의 NA는 test셋의 타겟이 원래 없어서 발생한 것이므로 무시 
# first_active_month 의 NA는 test셋에서 발생함... interval(구매일-첫 카드 구매일) 계산을 위해 해당 ID purchase_date의 가장 옛날값으로 대체
df.isna().sum().sort_values(ascending=False)
# Out:
# target                  11825698
# category_2               2764609
# category_3                234081
# merchant_id               164697
# first_active_month            55
# card_id                        0
# city_id                        0
# category_1                     0
# installments                   0
# merchant_category_id           0
# purchase_amount                0
# month_lag                      0
# feature_3                      0
# purchase_date                  0
# state_id                       0
# subsector_id                   0
# feature_1                      0
# feature_2                      0
# authorized_flag                0
# dtype: int64

# %%
#category_2 / category_3 / merchant_id 에서 가장 많이 나온 값으로 NA 대체
df.category_2.fillna(df.category_2.value_counts().index[0],inplace=True)
df.category_2=df.category_2.astype('int')
df.category_3.fillna(df.category_3.value_counts().index[0],inplace=True)
df.merchant_id.fillna(df.merchant_id.value_counts().index[0],inplace=True)
df.isna().sum()
# Out:
# authorized_flag                0
# card_id                        0
# city_id                        0
# category_1                     0
# installments                   0
# category_3                     0
# merchant_category_id           0
# merchant_id                    0
# month_lag                      0
# purchase_amount                0
# purchase_date                  0
# category_2                     0
# state_id                       0
# subsector_id                   0
# first_active_month            55
# feature_1                      0
# feature_2                      0
# feature_3                      0
# target                  11825698
# dtype: int64

# %%
# first_active_month의 NA는 id='C_ID_c27b4f80f7'에서만 발생하였으며, purchase_date의 가장 옛날값(2017-03)으로 대체
df.loc[df['first_active_month'].isna()].sort_values(by='purchase_date')
# Out:
#          authorized_flag          card_id  city_id category_1  installments  \
# 29021171               N  C_ID_c27b4f80f7       -1          Y            10
# 29021198               N  C_ID_c27b4f80f7       -1          Y            10
# 29021174               N  C_ID_c27b4f80f7       -1          Y            10
# 29021185               N  C_ID_c27b4f80f7       -1          Y            10
# 29021219               N  C_ID_c27b4f80f7       -1          Y            10
# 29021216               Y  C_ID_c27b4f80f7       -1          Y             1
# 29021212               Y  C_ID_c27b4f80f7       -1          Y             1
# 29021177               N  C_ID_c27b4f80f7       -1          Y             6
# 29021184               N  C_ID_c27b4f80f7       -1          Y             6
# 29021201               N  C_ID_c27b4f80f7       -1          Y             1
# 29021213               N  C_ID_c27b4f80f7       -1          Y             1
# 29021167               N  C_ID_c27b4f80f7       -1          Y             1
# 29021214               N  C_ID_c27b4f80f7       -1          Y             1
# 29021209               N  C_ID_c27b4f80f7       -1          Y             1
# 29021188               N  C_ID_c27b4f80f7       -1          Y             1
# 29021208               N  C_ID_c27b4f80f7       -1          Y             1
# 29021204               N  C_ID_c27b4f80f7       -1          Y             1
# 29021186               N  C_ID_c27b4f80f7       -1          Y             1
# 29021179               N  C_ID_c27b4f80f7       -1          Y             1
# 29021218               N  C_ID_c27b4f80f7       -1          Y             1
# 29021180               N  C_ID_c27b4f80f7       -1          Y             1
# 29021221               N  C_ID_c27b4f80f7       -1          Y             1
# 29021193               N  C_ID_c27b4f80f7       -1          Y             1
# 29021203               N  C_ID_c27b4f80f7       -1          Y             1
# 29021205               N  C_ID_c27b4f80f7       -1          Y             1
# 29021215               N  C_ID_c27b4f80f7       -1          Y             1
# 29021200               N  C_ID_c27b4f80f7       -1          Y             1
# 29021170               N  C_ID_c27b4f80f7       -1          Y             1
# 29021176               N  C_ID_c27b4f80f7       -1          Y             1
# 29021196               N  C_ID_c27b4f80f7       -1          Y             1
# 29021183               N  C_ID_c27b4f80f7       -1          Y             1
# 29021206               N  C_ID_c27b4f80f7       -1          Y             1
# 29021207               N  C_ID_c27b4f80f7       -1          Y             1
# 29021189               N  C_ID_c27b4f80f7       -1          Y             1
# 29021182               N  C_ID_c27b4f80f7       -1          Y             1
# 29021211               N  C_ID_c27b4f80f7       -1          Y             1
# 29021175               N  C_ID_c27b4f80f7       -1          Y             1
# 29021220               N  C_ID_c27b4f80f7       -1          Y             1
# 29021173               N  C_ID_c27b4f80f7       -1          Y             1
# 29021210               N  C_ID_c27b4f80f7       -1          Y             1
# 29021195               N  C_ID_c27b4f80f7       -1          Y             1
# 29021194               N  C_ID_c27b4f80f7       -1          Y             1
# 29021169               N  C_ID_c27b4f80f7       -1          Y             1
# 29021202               N  C_ID_c27b4f80f7       -1          Y             1
# 29021217               N  C_ID_c27b4f80f7       -1          Y             1
# 29021178               N  C_ID_c27b4f80f7       -1          Y             1
# 29021190               N  C_ID_c27b4f80f7       -1          Y             1
# 29021172               N  C_ID_c27b4f80f7       -1          Y             1
# 29021192               N  C_ID_c27b4f80f7       -1          Y             1
# 29021181               N  C_ID_c27b4f80f7       -1          Y             1
# 29021168               Y  C_ID_c27b4f80f7       -1          Y             1
# 29021191               N  C_ID_c27b4f80f7      175          N             1
# 29021187               N  C_ID_c27b4f80f7       -1          Y             1
# 29021199               N  C_ID_c27b4f80f7       -1          Y             1
# 29021197               N  C_ID_c27b4f80f7       -1          Y             1
#
#          category_3  merchant_category_id      merchant_id  month_lag  \
# 29021171          C                   511  M_ID_b9dcf28cb9        -11
# 29021198          C                   511  M_ID_b9dcf28cb9        -11
# 29021174          C                   511  M_ID_b9dcf28cb9        -11
# 29021185          C                   511  M_ID_b9dcf28cb9        -11
# 29021219          C                   511  M_ID_b9dcf28cb9        -11
# 29021216          B                   511  M_ID_b9dcf28cb9        -11
# 29021212          B                   111  M_ID_21f1585175         -9
# 29021177          C                   111  M_ID_21f1585175         -8
# 29021184          C                   111  M_ID_21f1585175         -8
# 29021201          B                   111  M_ID_21f1585175         -8
# 29021213          B                   111  M_ID_21f1585175         -8
# 29021167          B                   111  M_ID_21f1585175         -8
# 29021214          B                   111  M_ID_21f1585175         -8
# 29021209          B                   111  M_ID_21f1585175         -8
# 29021188          B                   111  M_ID_21f1585175         -7
# 29021208          B                   111  M_ID_21f1585175         -7
# 29021204          B                   111  M_ID_21f1585175         -7
# 29021186          B                   111  M_ID_21f1585175         -7
# 29021179          B                   111  M_ID_21f1585175         -7
# 29021218          B                   111  M_ID_21f1585175         -6
# 29021180          B                   111  M_ID_21f1585175         -6
# 29021221          B                   111  M_ID_21f1585175         -6
# 29021193          B                   111  M_ID_21f1585175         -6
# 29021203          B                   111  M_ID_21f1585175         -6
# 29021205          B                   111  M_ID_21f1585175         -5
# 29021215          B                   111  M_ID_21f1585175         -5
# 29021200          B                   111  M_ID_21f1585175         -5
# 29021170          B                   111  M_ID_21f1585175         -5
# 29021176          B                   111  M_ID_21f1585175         -5
# 29021196          B                   111  M_ID_21f1585175         -4
# 29021183          B                   111  M_ID_21f1585175         -4
# 29021206          B                   111  M_ID_21f1585175         -4
# 29021207          B                   111  M_ID_21f1585175         -4
# 29021189          B                   111  M_ID_21f1585175         -4
# 29021182          B                   111  M_ID_21f1585175         -3
# 29021211          B                   111  M_ID_21f1585175         -3
# 29021175          B                   111  M_ID_21f1585175         -3
# 29021220          B                   111  M_ID_21f1585175         -3
# 29021173          B                   111  M_ID_21f1585175         -3
# 29021210          B                   111  M_ID_21f1585175         -2
# 29021195          B                   111  M_ID_21f1585175         -2
# 29021194          B                   111  M_ID_21f1585175         -2
# 29021169          B                   111  M_ID_21f1585175         -2
# 29021202          B                   111  M_ID_21f1585175         -2
# 29021217          B                   111  M_ID_21f1585175         -1
# 29021178          B                   111  M_ID_21f1585175         -1
# 29021190          B                   111  M_ID_21f1585175         -1
# 29021172          B                   111  M_ID_21f1585175         -1
# 29021192          B                   111  M_ID_21f1585175         -1
# 29021181          B                   111  M_ID_21f1585175          0
# 29021168          B                   111  M_ID_21f1585175          0
# 29021191          B                   111  M_ID_21f1585175          0
# 29021187          B                   111  M_ID_21f1585175          0
# 29021199          B                   111  M_ID_21f1585175          0
# 29021197          B                   111  M_ID_21f1585175          0
#
#           purchase_amount        purchase_date  category_2  state_id  \
# 29021171        -0.056289  2017-03-09 01:34:22           1        -1
# 29021198        -0.407564  2017-03-09 01:46:07           1        -1
# 29021174        -0.056289  2017-03-10 20:41:16           1        -1
# 29021185        -0.056289  2017-03-11 02:46:55           1        -1
# 29021219        -0.407564  2017-03-11 02:57:50           1        -1
# 29021216        -0.745405  2017-03-25 00:36:49           1        -1
# 29021212        -0.745405  2017-05-12 23:15:44           1        -1
# 29021177        -0.351109  2017-06-12 11:35:10           1        -1
# 29021184        -0.351109  2017-06-15 11:47:24           1        -1
# 29021201        -0.680941  2017-06-15 12:29:25           1        -1
# 29021213        -0.680941  2017-06-18 10:30:27           1        -1
# 29021167        -0.680941  2017-06-21 11:20:20           1        -1
# 29021214        -0.680941  2017-06-24 11:07:14           1        -1
# 29021209        -0.680941  2017-06-27 11:03:14           1        -1
# 29021188        -0.680941  2017-07-15 11:19:34           1        -1
# 29021208        -0.680941  2017-07-18 10:04:23           1        -1
# 29021204        -0.680941  2017-07-21 11:03:09           1        -1
# 29021186        -0.680941  2017-07-24 11:25:13           1        -1
# 29021179        -0.680941  2017-07-27 10:06:17           1        -1
# 29021218        -0.680941  2017-08-15 10:34:13           1        -1
# 29021180        -0.680941  2017-08-18 10:57:13           1        -1
# 29021221        -0.680941  2017-08-21 11:49:17           1        -1
# 29021193        -0.680941  2017-08-24 10:54:15           1        -1
# 29021203        -0.680941  2017-08-27 11:59:19           1        -1
# 29021205        -0.680941  2017-09-15 14:42:16           1        -1
# 29021215        -0.680941  2017-09-18 13:07:06           1        -1
# 29021200        -0.680941  2017-09-21 13:09:10           1        -1
# 29021170        -0.680941  2017-09-24 13:03:04           1        -1
# 29021176        -0.680941  2017-09-27 14:07:24           1        -1
# 29021196        -0.680941  2017-10-15 13:45:19           1        -1
# 29021183        -0.680941  2017-10-18 13:45:10           1        -1
# 29021206        -0.680941  2017-10-21 13:34:11           1        -1
# 29021207        -0.680941  2017-10-24 13:13:09           1        -1
# 29021189        -0.680941  2017-10-27 12:52:10           1        -1
# 29021182        -0.680941  2017-11-15 13:22:40           1        -1
# 29021211        -0.680941  2017-11-18 13:53:21           1        -1
# 29021175        -0.680941  2017-11-21 13:55:13           1        -1
# 29021220        -0.680941  2017-11-24 13:44:09           1        -1
# 29021173        -0.680941  2017-11-27 12:01:28           1        -1
# 29021210        -0.680941  2017-12-15 11:13:41           1        -1
# 29021195        -0.680941  2017-12-18 11:23:07           1        -1
# 29021194        -0.680941  2017-12-21 10:00:12           1        -1
# 29021169        -0.680941  2017-12-24 11:47:06           1        -1
# 29021202        -0.680941  2017-12-27 11:03:14           1        -1
# 29021217        -0.680941  2018-01-15 11:18:21           1        -1
# 29021178        -0.680941  2018-01-18 10:40:09           1        -1
# 29021190        -0.680941  2018-01-21 11:28:19           1        -1
# 29021172        -0.680941  2018-01-24 10:38:27           1        -1
# 29021192        -0.680941  2018-01-27 10:11:04           1        -1
# 29021181        -0.680941  2018-02-15 11:04:27           1        -1
# 29021168        -0.745405  2018-02-15 11:05:56           1        -1
# 29021191        -0.680941  2018-02-18 11:00:11           1        16
# 29021187        -0.680941  2018-02-21 10:57:12           1        -1
# 29021199        -0.680941  2018-02-24 10:16:08           1        -1
# 29021197        -0.680941  2018-02-27 11:10:45           1        -1
#
#           subsector_id first_active_month  feature_1  feature_2  feature_3  \
# 29021171             7                NaN          5          2          1
# 29021198             7                NaN          5          2          1
# 29021174             7                NaN          5          2          1
# 29021185             7                NaN          5          2          1
# 29021219             7                NaN          5          2          1
# 29021216             7                NaN          5          2          1
# 29021212            36                NaN          5          2          1
# 29021177            36                NaN          5          2          1
# 29021184            36                NaN          5          2          1
# 29021201            36                NaN          5          2          1
# 29021213            36                NaN          5          2          1
# 29021167            36                NaN          5          2          1
# 29021214            36                NaN          5          2          1
# 29021209            36                NaN          5          2          1
# 29021188            36                NaN          5          2          1
# 29021208            36                NaN          5          2          1
# 29021204            36                NaN          5          2          1
# 29021186            36                NaN          5          2          1
# 29021179            36                NaN          5          2          1
# 29021218            36                NaN          5          2          1
# 29021180            36                NaN          5          2          1
# 29021221            36                NaN          5          2          1
# 29021193            36                NaN          5          2          1
# 29021203            36                NaN          5          2          1
# 29021205            36                NaN          5          2          1
# 29021215            36                NaN          5          2          1
# 29021200            36                NaN          5          2          1
# 29021170            36                NaN          5          2          1
# 29021176            36                NaN          5          2          1
# 29021196            36                NaN          5          2          1
# 29021183            36                NaN          5          2          1
# 29021206            36                NaN          5          2          1
# 29021207            36                NaN          5          2          1
# 29021189            36                NaN          5          2          1
# 29021182            36                NaN          5          2          1
# 29021211            36                NaN          5          2          1
# 29021175            36                NaN          5          2          1
# 29021220            36                NaN          5          2          1
# 29021173            36                NaN          5          2          1
# 29021210            36                NaN          5          2          1
# 29021195            36                NaN          5          2          1
# 29021194            36                NaN          5          2          1
# 29021169            36                NaN          5          2          1
# 29021202            36                NaN          5          2          1
# 29021217            36                NaN          5          2          1
# 29021178            36                NaN          5          2          1
# 29021190            36                NaN          5          2          1
# 29021172            36                NaN          5          2          1
# 29021192            36                NaN          5          2          1
# 29021181            36                NaN          5          2          1
# 29021168            36                NaN          5          2          1
# 29021191            36                NaN          5          2          1
# 29021187            36                NaN          5          2          1
# 29021199            36                NaN          5          2          1
# 29021197            36                NaN          5          2          1
#
#           target
# 29021171     NaN
# 29021198     NaN
# 29021174     NaN
# 29021185     NaN
# 29021219     NaN
# 29021216     NaN
# 29021212     NaN
# 29021177     NaN
# 29021184     NaN
# 29021201     NaN
# 29021213     NaN
# 29021167     NaN
# 29021214     NaN
# 29021209     NaN
# 29021188     NaN
# 29021208     NaN
# 29021204     NaN
# 29021186     NaN
# 29021179     NaN
# 29021218     NaN
# 29021180     NaN
# 29021221     NaN
# 29021193     NaN
# 29021203     NaN
# 29021205     NaN
# 29021215     NaN
# 29021200     NaN
# 29021170     NaN
# 29021176     NaN
# 29021196     NaN
# 29021183     NaN
# 29021206     NaN
# 29021207     NaN
# 29021189     NaN
# 29021182     NaN
# 29021211     NaN
# 29021175     NaN
# 29021220     NaN
# 29021173     NaN
# 29021210     NaN
# 29021195     NaN
# 29021194     NaN
# 29021169     NaN
# 29021202     NaN
# 29021217     NaN
# 29021178     NaN
# 29021190     NaN
# 29021172     NaN
# 29021192     NaN
# 29021181     NaN
# 29021168     NaN
# 29021191     NaN
# 29021187     NaN
# 29021199     NaN
# 29021197     NaN

# %%
df.first_active_month.fillna('2017-03',inplace=True)
df.loc[df.card_id=='C_ID_c27b4f80f7'].head(1)
# Out:
#          authorized_flag          card_id  city_id category_1  installments  \
# 29021167               N  C_ID_c27b4f80f7       -1          Y             1
#
#          category_3  merchant_category_id      merchant_id  month_lag  \
# 29021167          B                   111  M_ID_21f1585175         -8
#
#           purchase_amount        purchase_date  category_2  state_id  \
# 29021167        -0.680941  2017-06-21 11:20:20           1        -1
#
#           subsector_id first_active_month  feature_1  feature_2  feature_3  \
# 29021167            36            2017-03          5          2          1
#
#           target
# 29021167     NaN

# %%
df.isna().sum()
# Out:
# authorized_flag                0
# card_id                        0
# city_id                        0
# category_1                     0
# installments                   0
# category_3                     0
# merchant_category_id           0
# merchant_id                    0
# month_lag                      0
# purchase_amount                0
# purchase_date                  0
# category_2                     0
# state_id                       0
# subsector_id                   0
# first_active_month             0
# feature_1                      0
# feature_2                      0
# feature_3                      0
# target                  11825698
# dtype: int64

# %%
#authorized_flag / category_1 → N/Y 값 0/1로 교체
df.authorized_flag=df.authorized_flag.apply(lambda x : 0 if x=="N" else 1)
df.category_1=df.category_1.apply(lambda x : 0 if x=="N" else 1)

# %% [markdown]
# ### 3) interval_month 생성

# %%
#interval_month 생성 (purchase_date - first_active_month)
df['purchase_date_dt']=df['purchase_date'].apply(lambda x : x[0:7])
df['purchase_date_dt']=pd.to_datetime(df['purchase_date_dt'],format='%Y-%m')
df['first_active_month_dt']=pd.to_datetime(df['first_active_month'])
df['interval_day']=df['purchase_date_dt'] - df['first_active_month_dt']

df['interval_month']=df['interval_day'].apply(lambda x: str(x)[:-14]).astype('int')//30
df.drop(columns=['purchase_date_dt','first_active_month_dt','interval_day'],inplace=True)

# %% [markdown]
# ### 4) datetime 분리

# %%
#datetime 변수 추가 (year / month )
df['purchase_date']=pd.to_datetime(df['purchase_date'])
df['year']=df['purchase_date'].dt.year
df['month']=df['purchase_date'].dt.month
df['weekday']=(df['purchase_date'].dt.dayofweek<6).astype('int')
df['weekend']=(df['purchase_date'].dt.dayofweek>=5).astype('int')

# %% [markdown]
# ### 5) purchase_amount_log1p 생성

# %%
df['purchase_amount_log1p']=np.log1p(df['purchase_amount'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31075392 entries, 0 to 31075391
# Data columns (total 25 columns):
# authorized_flag          int64
# card_id                  object
# city_id                  int16
# category_1               int64
# installments             int16
# category_3               object
# merchant_category_id     int16
# merchant_id              object
# month_lag                int8
# purchase_amount          float32
# purchase_date            datetime64[ns]
# category_2               int32
# state_id                 int8
# subsector_id             int8
# first_active_month       object
# feature_1                uint8
# feature_2                uint8
# feature_3                uint8
# target                   float64
# interval_month           int32
# year                     int64
# month                    int64
# weekday                  int32
# weekend                  int32
# purchase_amount_log1p    float32
# dtypes: datetime64[ns](1), float32(2), float64(1), int16(3), int32(4), int64(4), int8(3), object(4), uint8(3)
# memory usage: 3.4+ GB

# %%
df.tail(3)
# Out:
#           authorized_flag          card_id  city_id  category_1  installments  \
# 31075389                1  C_ID_c07707ff74      194           0             2
# 31075390                1  C_ID_611d4d588f      302           0             1
# 31075391                1  C_ID_1320dee851      142           0             0
#
#          category_3  merchant_category_id      merchant_id  month_lag  \
# 31075389          C                    87  M_ID_7dabac675c          1
# 31075390          B                   307  M_ID_ee5a6f6a35          2
# 31075391          A                   309  M_ID_7754b67f3b          2
#
#           purchase_amount  ... feature_1  feature_2  feature_3  target  \
# 31075389        -0.476431  ...         5          1          1     NaN
# 31075390        -0.731881  ...         2          2          0     NaN
# 31075391        -0.701828  ...         3          1          1     NaN
#
#          interval_month  year  month  weekday  weekend  purchase_amount_log1p
# 31075389             30  2018      3        1        0              -0.647086
# 31075390              5  2018      3        0        1              -1.316325
# 31075391              8  2018      4        1        0              -1.210086
#
# [3 rows x 25 columns]

# %%
df.to_csv("D:/kaggle/ELO/data/new/df.csv",encoding='utf-8',index=None)

# %% [markdown]
# # 기존 변수별 생성할 파생변수 정리
#
# ### 01. authorized_flag
# * authroized_flag_sum  : ID별 승인된 거래 개수
# * authroized_flag_mean : ID별 평균 승인률
#
# ### 02. card_id
# * card_id_count : ID별 나타난 transaction의 개수
#
# ### 03. city_id
# * city_id_nunique : ID별 city_id 개수
#
# ### 04. category_1
# * category_1_sum: ID별 Y의 개수
# * category_1_mean: ID별 평균 Y 비율
#
# ### 05. installments
# * installments_min  : ID별 최소 할부개월
# * installments_max  : ID별 최대 할부개월
# * installments_mean : ID별 평균 할부개월
#
#
# ### 06. category_3
# * category_3_nunique : ID별 category_3 개수
#
# ### 07. merchant_category_id
# * merchant_category_id_nunique : ID별 merchant_category_id 개수
#
# ### 08. merchant_id
# * merchant_id_nunique : ID별 merchant_id 개수
#
# ### 09. month_lag
# * month_lag_min  : ID별 기준일 시차 최소(ID별로 기준일이 다른듯 하다)
# * month_lag_max  : ID별 기준일 시차 최대(ID별로 기준일이 다른듯 하다)
# * month_lag_mean : ID별 기준일 시차 평균(ID별로 기준일이 다른듯 하다)
#
# ### 10. purchase_amount(log1p 로 진행)
# * purchase_amount_log1p_min : ID별 최소 사용 금액
# * purchase_amount_log1p_max : ID별 최대 사용금액
# * purchase_amount_log1p_sum : ID별 사용 금액 합
# * purchase_amount_log1p_mean: ID별 평균 사용금액
#
# ### 11.  purchase_date
# * purchase_date_min: ID별 가장 과거 구매일
# * purchase_date_max: ID별 최근 구매일
#
# * year_nunique: ID별 구매 년도 개수
# * month_nunique: ID별 구매 월 개수
# * weekday_sum: ID별 총 평일 구매 횟수
# * weekday_mean: ID별 평일 구매 비율
# * weekend_sum: ID별 총 주말 구매 횟수
# * weekend_mean: ID별 주말 구매 비율
#
# ### 12. category_2
# * category_2_nunique: ID별 category_2 개수
#
# ### 13. state_id
# * state_id_nunique: ID별 state_id 개수
#
# ### 14. subsector_id
# * subsector_id_nunique: ID별 subsector_id 개수
#
# ### 15. interval_month
# * interval_month_min : ID별 구매일과 첫 구매일 시차의 최소
# * interval_month_max : ID별 구매일과 첫 구매일 시차의 최대
# * interval_month_mean: ID별 구매일과 첫 구매일 시차의 평균

# %%
# %%time
train=pd.read_csv("D:/kaggle/ELO/data/new/train.csv",encoding='utf-8')
test=pd.read_csv("D:/kaggle/ELO/data/new/test.csv",encoding='utf-8')
df=pd.read_csv("D:/kaggle/ELO/data/new/df.csv",encoding='utf-8')

train, _ = reduce_mem_usage(train,fillna=False)
test, _ = reduce_mem_usage(test,fillna=False)
df, _ = reduce_mem_usage(df,fillna=False)

df['purchase_date']=pd.to_datetime(df['purchase_date'])
# Out:
# Memory usage of properties dataframe is : 9.243148803710938  MB
# ******************************
# Column:  feature_1
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_2
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_3
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  4.429072380065918  MB
# This is  47.91735450897139 % of the initial size
# Memory usage of properties dataframe is : 5.6591339111328125  MB
# ******************************
# Column:  feature_1
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_2
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_3
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  target
# dtype before:  float64
# [*]skip target cause of NA value
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  3.183316230773926  MB
# This is  56.25094370910032 % of the initial size
# Memory usage of properties dataframe is : 5927.1607666015625  MB
# ******************************
# Column:  authorized_flag
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  city_id
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  category_1
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  installments
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  merchant_category_id
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  month_lag
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  purchase_amount
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  category_2
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  state_id
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  subsector_id
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  feature_1
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_2
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_3
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  target
# dtype before:  float64
# [*]skip target cause of NA value
# ******************************
# Column:  interval_month
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  year
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  month
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekend
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  purchase_amount_log1p
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  2281.9569702148438  MB
# This is  38.50000126659703 % of the initial size
# Wall time: 3min 17s

# %%
def aggregate_func(dataframe):
    
    agg_func = {

    'authorized_flag': ['sum', 'mean'],
    'city_id': ['nunique'],
    'category_1': ['sum','mean'],
    'installments': ['min','max','mean'],
    'category_3': ['nunique'],
    'merchant_category_id': ['nunique'],
    'merchant_id': ['nunique'],
    'month_lag': ['min','max','mean'],
    'purchase_amount_log1p': ['min','max','sum','mean'],
    'purchase_date': ['min','max'],
    'year': ['nunique'],
    'month': ['nunique'],
    'weekday': ['sum','mean'],
    'weekend': ['sum','mean'],
    'category_2': ['nunique'],
    'state_id': ['nunique'],
    'subsector_id': ['nunique'],
    'interval_month': ['min','max','mean']                 
    }
    
    agg_dataframe = dataframe.groupby(['card_id']).agg(agg_func)
    agg_dataframe.columns = ['_'.join(col).strip() for col in agg_dataframe.columns.values]
    agg_dataframe.reset_index(inplace=True)
    
    ref_df = (dataframe.groupby('card_id')
          .size()
          .reset_index(name='card_id_count'))
    
    agg_dataframe = pd.merge(ref_df, agg_dataframe, on='card_id', how='left')
    
    return agg_dataframe

# %%
df_new = aggregate_func(df)
df_new.tail(3)
# Out:
#                 card_id  card_id_count  authorized_flag_sum  \
# 325537  C_ID_ffff756266             25                 15.0
# 325538  C_ID_ffff828181            198                174.0
# 325539  C_ID_fffffd5772             87                 78.0
#
#         authorized_flag_mean  city_id_nunique  category_1_sum  \
# 325537              0.600000                2             3.0
# 325538              0.878788               12            11.0
# 325539              0.896552                4            33.0
#
#         category_1_mean  installments_min  installments_max  \
# 325537         0.120000                -1                12
# 325538         0.055556                -1                 4
# 325539         0.379310                -1                 3
#
#         installments_mean  ...  weekday_sum  weekday_mean  weekend_sum  \
# 325537           3.160000  ...         23.0      0.920000          2.0
# 325538           1.202020  ...        185.0      0.934343         47.0
# 325539           1.034483  ...         78.0      0.896552         21.0
#
#         weekend_mean  category_2_nunique  state_id_nunique  \
# 325537      0.080000                   1                 2
# 325538      0.237374                   4                 7
# 325539      0.241379                   2                 3
#
#         subsector_id_nunique  interval_month_min  interval_month_max  \
# 325537                    10                   3                  18
# 325538                    24                  24                  39
# 325539                    10                   0                   7
#
#         interval_month_mean
# 325537             7.840000
# 325538            31.232323
# 325539             4.160920
#
# [3 rows x 34 columns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325540 entries, 0 to 325539
# Data columns (total 34 columns):
# card_id                         325540 non-null object
# card_id_count                   325540 non-null int64
# authorized_flag_sum             325540 non-null float64
# authorized_flag_mean            325540 non-null float64
# city_id_nunique                 325540 non-null int64
# category_1_sum                  325540 non-null float64
# category_1_mean                 325540 non-null float64
# installments_min                325540 non-null int16
# installments_max                325540 non-null int16
# installments_mean               325540 non-null float64
# category_3_nunique              325540 non-null int64
# merchant_category_id_nunique    325540 non-null int64
# merchant_id_nunique             325540 non-null int64
# month_lag_min                   325540 non-null int8
# month_lag_max                   325540 non-null int8
# month_lag_mean                  325540 non-null float64
# purchase_amount_log1p_min       325540 non-null float32
# purchase_amount_log1p_max       325540 non-null float32
# purchase_amount_log1p_sum       325540 non-null float32
# purchase_amount_log1p_mean      325540 non-null float32
# purchase_date_min               325540 non-null datetime64[ns]
# purchase_date_max               325540 non-null datetime64[ns]
# year_nunique                    325540 non-null int64
# month_nunique                   325540 non-null int64
# weekday_sum                     325540 non-null float64
# weekday_mean                    325540 non-null float64
# weekend_sum                     325540 non-null float64
# weekend_mean                    325540 non-null float64
# category_2_nunique              325540 non-null int64
# state_id_nunique                325540 non-null int64
# subsector_id_nunique            325540 non-null int64
# interval_month_min              325540 non-null int8
# interval_month_max              325540 non-null int8
# interval_month_mean             325540 non-null float64
# dtypes: datetime64[ns](2), float32(4), float64(11), int16(2), int64(10), int8(4), object(1)
# memory usage: 69.5+ MB

# %%
train_test=pd.concat([train,test],axis=0).reset_index(drop=True)
train_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325540 entries, 0 to 325539
# Data columns (total 6 columns):
# first_active_month    325539 non-null object
# card_id               325540 non-null object
# feature_1             325540 non-null uint8
# feature_2             325540 non-null uint8
# feature_3             325540 non-null uint8
# target                201917 non-null float32
# dtypes: float32(1), object(2), uint8(3)
# memory usage: 7.1+ MB

# %%
df_base=pd.merge(df_new,train_test,on='card_id',how='left')
df_base.tail(3)
# Out:
#                 card_id  card_id_count  authorized_flag_sum  \
# 325537  C_ID_ffff756266             25                 15.0
# 325538  C_ID_ffff828181            198                174.0
# 325539  C_ID_fffffd5772             87                 78.0
#
#         authorized_flag_mean  city_id_nunique  category_1_sum  \
# 325537              0.600000                2             3.0
# 325538              0.878788               12            11.0
# 325539              0.896552                4            33.0
#
#         category_1_mean  installments_min  installments_max  \
# 325537         0.120000                -1                12
# 325538         0.055556                -1                 4
# 325539         0.379310                -1                 3
#
#         installments_mean  ...  state_id_nunique  subsector_id_nunique  \
# 325537           3.160000  ...                 2                    10
# 325538           1.202020  ...                 7                    24
# 325539           1.034483  ...                 3                    10
#
#         interval_month_min  interval_month_max  interval_month_mean  \
# 325537                   3                  18             7.840000
# 325538                  24                  39            31.232323
# 325539                   0                   7             4.160920
#
#         first_active_month  feature_1  feature_2  feature_3    target
# 325537             2016-10          5          1          1       NaN
# 325538             2015-01          2          1          0 -0.600063
# 325539             2017-08          2          1          0 -1.073077
#
# [3 rows x 39 columns]

# %%
df_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325540 entries, 0 to 325539
# Data columns (total 39 columns):
# card_id                         325540 non-null object
# card_id_count                   325540 non-null int64
# authorized_flag_sum             325540 non-null float64
# authorized_flag_mean            325540 non-null float64
# city_id_nunique                 325540 non-null int64
# category_1_sum                  325540 non-null float64
# category_1_mean                 325540 non-null float64
# installments_min                325540 non-null int16
# installments_max                325540 non-null int16
# installments_mean               325540 non-null float64
# category_3_nunique              325540 non-null int64
# merchant_category_id_nunique    325540 non-null int64
# merchant_id_nunique             325540 non-null int64
# month_lag_min                   325540 non-null int8
# month_lag_max                   325540 non-null int8
# month_lag_mean                  325540 non-null float64
# purchase_amount_log1p_min       325540 non-null float32
# purchase_amount_log1p_max       325540 non-null float32
# purchase_amount_log1p_sum       325540 non-null float32
# purchase_amount_log1p_mean      325540 non-null float32
# purchase_date_min               325540 non-null datetime64[ns]
# purchase_date_max               325540 non-null datetime64[ns]
# year_nunique                    325540 non-null int64
# month_nunique                   325540 non-null int64
# weekday_sum                     325540 non-null float64
# weekday_mean                    325540 non-null float64
# weekend_sum                     325540 non-null float64
# weekend_mean                    325540 non-null float64
# category_2_nunique              325540 non-null int64
# state_id_nunique                325540 non-null int64
# subsector_id_nunique            325540 non-null int64
# interval_month_min              325540 non-null int8
# interval_month_max              325540 non-null int8
# interval_month_mean             325540 non-null float64
# first_active_month              325539 non-null object
# feature_1                       325540 non-null uint8
# feature_2                       325540 non-null uint8
# feature_3                       325540 non-null uint8
# target                          201917 non-null float32
# dtypes: datetime64[ns](2), float32(5), float64(11), int16(2), int64(10), int8(4), object(2), uint8(3)
# memory usage: 74.2+ MB

# %%
#train,test card_id 보존
train_id=np.unique(tr_train.card_id)
test_id=np.unique(tr_test.card_id)

# %%
df_train=df_base.loc[df_base.card_id.isin(train_id)]
df_test=df_base.loc[df_base.card_id.isin(test_id)]
df_test=df_test.drop(columns=['target'])

# %%
df_train.tail(1)
# Out:
#                 card_id  card_id_count  authorized_flag_sum  \
# 325539  C_ID_fffffd5772             87                 78.0
#
#         authorized_flag_mean  city_id_nunique  category_1_sum  \
# 325539              0.896552                4            33.0
#
#         category_1_mean  installments_min  installments_max  \
# 325539          0.37931                -1                 3
#
#         installments_mean  ...  state_id_nunique  subsector_id_nunique  \
# 325539           1.034483  ...                 3                    10
#
#         interval_month_min  interval_month_max  interval_month_mean  \
# 325539                   0                   7              4.16092
#
#         first_active_month  feature_1  feature_2  feature_3    target
# 325539             2017-08          2          1          0 -1.073077
#
# [1 rows x 39 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201917 entries, 0 to 325539
# Data columns (total 39 columns):
# card_id                         201917 non-null object
# card_id_count                   201917 non-null int64
# authorized_flag_sum             201917 non-null float64
# authorized_flag_mean            201917 non-null float64
# city_id_nunique                 201917 non-null int64
# category_1_sum                  201917 non-null float64
# category_1_mean                 201917 non-null float64
# installments_min                201917 non-null int16
# installments_max                201917 non-null int16
# installments_mean               201917 non-null float64
# category_3_nunique              201917 non-null int64
# merchant_category_id_nunique    201917 non-null int64
# merchant_id_nunique             201917 non-null int64
# month_lag_min                   201917 non-null int8
# month_lag_max                   201917 non-null int8
# month_lag_mean                  201917 non-null float64
# purchase_amount_log1p_min       201917 non-null float32
# purchase_amount_log1p_max       201917 non-null float32
# purchase_amount_log1p_sum       201917 non-null float32
# purchase_amount_log1p_mean      201917 non-null float32
# purchase_date_min               201917 non-null datetime64[ns]
# purchase_date_max               201917 non-null datetime64[ns]
# year_nunique                    201917 non-null int64
# month_nunique                   201917 non-null int64
# weekday_sum                     201917 non-null float64
# weekday_mean                    201917 non-null float64
# weekend_sum                     201917 non-null float64
# weekend_mean                    201917 non-null float64
# category_2_nunique              201917 non-null int64
# state_id_nunique                201917 non-null int64
# subsector_id_nunique            201917 non-null int64
# interval_month_min              201917 non-null int8
# interval_month_max              201917 non-null int8
# interval_month_mean             201917 non-null float64
# first_active_month              201917 non-null object
# feature_1                       201917 non-null uint8
# feature_2                       201917 non-null uint8
# feature_3                       201917 non-null uint8
# target                          201917 non-null float32
# dtypes: datetime64[ns](2), float32(5), float64(11), int16(2), int64(10), int8(4), object(2), uint8(3)
# memory usage: 46.0+ MB

# %%
df_test.tail(1)
# Out:
#                 card_id  card_id_count  authorized_flag_sum  \
# 325537  C_ID_ffff756266             25                 15.0
#
#         authorized_flag_mean  city_id_nunique  category_1_sum  \
# 325537                   0.6                2             3.0
#
#         category_1_mean  installments_min  installments_max  \
# 325537             0.12                -1                12
#
#         installments_mean  ...  category_2_nunique  state_id_nunique  \
# 325537               3.16  ...                   1                 2
#
#         subsector_id_nunique  interval_month_min  interval_month_max  \
# 325537                    10                   3                  18
#
#         interval_month_mean  first_active_month  feature_1  feature_2  \
# 325537                 7.84             2016-10          5          1
#
#         feature_3
# 325537          1
#
# [1 rows x 38 columns]

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123623 entries, 1 to 325537
# Data columns (total 38 columns):
# card_id                         123623 non-null object
# card_id_count                   123623 non-null int64
# authorized_flag_sum             123623 non-null float64
# authorized_flag_mean            123623 non-null float64
# city_id_nunique                 123623 non-null int64
# category_1_sum                  123623 non-null float64
# category_1_mean                 123623 non-null float64
# installments_min                123623 non-null int16
# installments_max                123623 non-null int16
# installments_mean               123623 non-null float64
# category_3_nunique              123623 non-null int64
# merchant_category_id_nunique    123623 non-null int64
# merchant_id_nunique             123623 non-null int64
# month_lag_min                   123623 non-null int8
# month_lag_max                   123623 non-null int8
# month_lag_mean                  123623 non-null float64
# purchase_amount_log1p_min       123623 non-null float32
# purchase_amount_log1p_max       123623 non-null float32
# purchase_amount_log1p_sum       123623 non-null float32
# purchase_amount_log1p_mean      123623 non-null float32
# purchase_date_min               123623 non-null datetime64[ns]
# purchase_date_max               123623 non-null datetime64[ns]
# year_nunique                    123623 non-null int64
# month_nunique                   123623 non-null int64
# weekday_sum                     123623 non-null float64
# weekday_mean                    123623 non-null float64
# weekend_sum                     123623 non-null float64
# weekend_mean                    123623 non-null float64
# category_2_nunique              123623 non-null int64
# state_id_nunique                123623 non-null int64
# subsector_id_nunique            123623 non-null int64
# interval_month_min              123623 non-null int8
# interval_month_max              123623 non-null int8
# interval_month_mean             123623 non-null float64
# first_active_month              123622 non-null object
# feature_1                       123623 non-null uint8
# feature_2                       123623 non-null uint8
# feature_3                       123623 non-null uint8
# dtypes: datetime64[ns](2), float32(4), float64(11), int16(2), int64(10), int8(4), object(2), uint8(3)
# memory usage: 27.7+ MB

# %%
################################################### 끝 여기 밑에는 테스트 코드 #########################################################

# %% [markdown]
# ## nunique 열
# * ['city_id','category_3','merchant_category_id','merchant_id','year','month','category_2','state_id','subsector_id']

# %%
#nunique 열 리스트 설정
n_unique_col=['city_id','category_3','merchant_category_id','merchant_id','year','month','category_2','state_id','subsector_id']

#nunique 열 생성
for i in range(len(n_unique_col)):
    nunique_basket=[]
   
    for j in range(len(df_new.card_id)):
        value=df.loc[df.card_id==df_new.card_id[j],n_unique_col[i]].nunique()
        nunique_basket.append(value)
        
    df_new['{}'.format(str(n_unique_col[i])+"_"+"nunique")]=nunique_basket
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-80f3eb5673ea> in <module>
#       7
#       8     for j in range(len(df_new.card_id)):
# ----> 9         value=df.loc[df.card_id==df_new.card_id[j],n_unique_col[i]].nunique()
#      10         nunique_basket.append(value)
#      11
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# KeyboardInterrupt:

# %% [markdown]
# ## sum 열
# * ['authorized_flag','category_1','weekday','weekend']

# %%
temp_df = df.groupby(['card_id']).agg(agg_func)
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     662         try:
# --> 663             return self._aggregate_series_fast(obj, func)
#     664         except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_fast(self, obj, func)
#     680         grouper = reduction.SeriesGrouper(obj, func, group_index, ngroups, dummy)
# --> 681         result, counts = grouper.get_result()
#     682         return result, counts
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     893         func = self._is_builtin_func(func)
# --> 894         f = lambda x: func(x, *args, **kwargs)
#     895
#
# ~\Anaconda3\lib\statistics.py in mode(data)
#     505         raise StatisticsError(
# --> 506                 'no unique mode; found %d equally common values' % len(table)
#     507                 )
#
# StatisticsError: no unique mode; found 2 equally common values
#
# During handling of the above exception, another exception occurred:
#
# StatisticsError                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     862             try:
# --> 863                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     864             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     899             try:
# --> 900                 result, counts = self.grouper.agg_series(obj, f)
#     901                 output[name] = self._try_cast(result, obj, numeric_only=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     664         except Exception:
# --> 665             return self._aggregate_series_pure_python(obj, func)
#     666
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_pure_python(self, obj, func)
#     693         for label, group in splitter:
# --> 694             res = func(group)
#     695             if result is None:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     893         func = self._is_builtin_func(func)
# --> 894         f = lambda x: func(x, *args, **kwargs)
#     895
#
# ~\Anaconda3\lib\statistics.py in mode(data)
#     505         raise StatisticsError(
# --> 506                 'no unique mode; found %d equally common values' % len(table)
#     507                 )
#
# StatisticsError: no unique mode; found 2 equally common values
#
# During handling of the above exception, another exception occurred:
#
# StatisticsError                           Traceback (most recent call last)
# <ipython-input-28-ee705fdd8afd> in <module>
# ----> 1 temp_df = df.groupby(['card_id']).agg(agg_func)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     227         func = _maybe_mangle_lambdas(func)
#     228
# --> 229         result, how = self._aggregate(func, _level=_level, *args, **kwargs)
#     230         if how is None:
#     231             return result
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     504
#     505                 try:
# --> 506                     result = _agg(arg, _agg_1dim)
#     507                 except SpecificationError:
#     508
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _agg(arg, func)
#     454                 result = OrderedDict()
#     455                 for fname, agg_how in arg.items():
# --> 456                     result[fname] = func(fname, agg_how)
#     457                 return result
#     458
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _agg_1dim(name, how, subset)
#     438                         "nested dictionary is ambiguous " "in aggregation"
#     439                     )
# --> 440                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     441
#     442             def _agg_2dim(name, how):
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     849             # but not the class list / tuple itself.
#     850             func_or_funcs = _maybe_mangle_lambdas(func_or_funcs)
# --> 851             ret = self._aggregate_multiple_funcs(func_or_funcs, (_level or 0) + 1)
#     852             if relabeling:
#     853                 ret.columns = columns
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_multiple_funcs(self, arg, _level)
#     928                 obj._reset_cache()
#     929                 obj._selection = name
# --> 930             results[name] = obj.aggregate(func)
#     931
#     932         if any(isinstance(x, DataFrame) for x in results.values()):
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     863                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     864             except Exception:
# --> 865                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     866
#     867             index = Index(sorted(result), name=self.grouper.names[0])
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_named(self, func, *args, **kwargs)
#     995         for name, group in self:
#     996             group.name = name
# --> 997             output = func(group, *args, **kwargs)
#     998             if isinstance(output, (Series, Index, np.ndarray)):
#     999                 raise Exception("Must produce aggregated value")
#
# ~\Anaconda3\lib\statistics.py in mode(data)
#     504     elif table:
#     505         raise StatisticsError(
# --> 506                 'no unique mode; found %d equally common values' % len(table)
#     507                 )
#     508     else:
#
# StatisticsError: no unique mode; found 2 equally common values

# %% [markdown]
# ## mean 열
# * ['authorized_flag','category_1','installments','month_lag','purchase_amount','weekday','weekend','interval_month']

# %% [markdown]
# ## min 열

# %% [markdown]
# ## max 열

# %% [markdown]
# ## count 열

# %%
temp_df=df.loc[:10000]
temp_df.tail()
# Out:
#        authorized_flag          card_id  city_id  category_1  installments  \
# 9996                 1  C_ID_cf58d5be10       17           0             1
# 9997                 1  C_ID_cf58d5be10       73           0             1
# 9998                 1  C_ID_cf58d5be10      331           0             1
# 9999                 1  C_ID_cf58d5be10      166           0             1
# 10000                1  C_ID_cf58d5be10      200           0             1
#
#       category_3  merchant_category_id      merchant_id  month_lag  \
# 9996           B                   818  M_ID_4bcf17b639         -7
# 9997           B                   818  M_ID_852a674b3e        -12
# 9998           B                   307  M_ID_b2fb4f93d1         -4
# 9999           B                   307  M_ID_4bf61484df         -8
# 10000          B                   278  M_ID_2f65280a18        -11
#
#        purchase_amount  ... first_active_month  feature_1  feature_2  \
# 9996         -0.506484  ...            2016-10          5          1
# 9997         -0.683045  ...            2016-10          5          1
# 9998         -0.637936  ...            2016-10          5          1
# 9999         -0.518445  ...            2016-10          5          1
# 10000        -0.682594  ...            2016-10          5          1
#
#        feature_3    target  interval_month  year  month  weekday  weekend
# 9996           1  0.854866               9  2017      7        0        1
# 9997           1  0.854866               4  2017      2        1        0
# 9998           1  0.854866              12  2017     10        1        0
# 9999           1  0.854866               8  2017      6        1        0
# 10000          1  0.854866               5  2017      3        1        0
#
# [5 rows x 24 columns]

# %%
new_df=pd.DataFrame(temp_df.card_id.unique(),columns=['card_id'])
new_df.head()
# Out:
#            card_id
# 0  C_ID_5037ff576e
# 1  C_ID_0e171c1b48
# 2  C_ID_fc8e41b9cf
# 3  C_ID_b271e7ab60
# 4  C_ID_4bed29d75c

# %%
n_unique_col=['city_id','category_3','merchant_category_id','merchant_id','year','month','category_2','state_id','subsector_id']
for i in range(len(n_unique_col)):
    temp=[]
   
    for j in range(len(new_df.card_id)):
        value=temp_df.loc[temp_df.card_id==new_df.card_id[j],n_unique_col[i]].nunique()
        temp.append(value)
        
    new_df['{}'.format(str(n_unique_col[i])+"_"+"nunique")]=temp

# %%
new_df.tail()
# Out:
#             card_id  city_id_nunique  category_3_nunique  \
# 35  C_ID_1964c39b55                9                   2
# 36  C_ID_65188857e6                9                   3
# 37  C_ID_b86ad6f26b                8                   2
# 38  C_ID_542f1fa442                2                   2
# 39  C_ID_cf58d5be10               14                   1
#
#     merchant_category_id_nunique  merchant_id_nunique  year_nunique  \
# 35                            42                   95             2
# 36                            42                  101             2
# 37                            30                   78             2
# 38                            24                   49             2
# 39                             6                   21             1
#
#     month_nunique  category_2_nunique  state_id_nunique  subsector_id_nunique
# 35              9                   5                 7                    25
# 36              8                   1                 3                    19
# 37              6                   2                 3                    16
# 38             12                   1                 2                    17
# 39              8                   5                 9                     5

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
# card_id                         40 non-null object
# city_id_nunique                 40 non-null int64
# category_3_nunique              40 non-null int64
# merchant_category_id_nunique    40 non-null int64
# merchant_id_nunique             40 non-null int64
# category_2_nunique              40 non-null int64
# state_id_nunique                40 non-null int64
# subsector_id_nunique            40 non-null int64
# dtypes: int64(7), object(1)
# memory usage: 2.6+ KB
