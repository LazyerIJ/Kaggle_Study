# %%
import os
import pandas as pd
import glob
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import gc

# %%
pd.set_option('max_columns', None)

# %%
input_dir = os.path.join('..', 'input')
file_csv = [file for file in os.listdir(input_dir)\
            if file.endswith('.csv')]
print(file_csv)
# Out:
# ['historical_transactions.csv', 'merchants.csv', 'new_merchant_transactions.csv', 'sample_submission.csv', 'train.csv', 'test.csv']

# %%
## Pandas@reduce dataframe memory
def reduce_mem_usage(props, fillna=False, fillval=None):
    start_mem_usg = props.memory_usage().sum() / 1024**2
    print("Memory usage of properties dataframe is :",start_mem_usg," MB")
    NAlist = [] # Keeps track of columns that have missing values filled in. 
    for col in props.columns:
        if props[col].dtype != object:  # Exclude strings
            
            # Print current column type
            print("******************************")
            print("Column: ", col)
            print("dtype before: ", props[col].dtype)
            
            # make variables for Int, max and min
            IsInt = False
            mx = props[col].max()
            mn = props[col].min()
            
            # Integer does not support NA, therefore, NA needs to be filled
            if not np.isfinite(props[col]).all(): 
                if not fillna:
                    print('[*]skip {} cause of NA value'.format(col))
                    continue
                NAlist.append(col)
                props[col].fillna(fillval,inplace=True)  
            
            # test if column can be converted to an integer
            asint = props[col].fillna(0).astype(np.int64)
            result = (props[col] - asint)
            result = result.sum()
            if result > -0.01 and result < 0.01:
                IsInt = True

            # Make Integer/unsigned Integer datatypes
            if IsInt:
                if mn >= 0:
                    if mx < pow(2, 8)-1:
                        props[col] = props[col].astype(np.uint8)
                    elif mx < pow(2, 16)-1:
                        props[col] = props[col].astype(np.uint16)
                    elif mx < pow(2, 32)-1:
                        props[col] = props[col].astype(np.uint32)
                    else:
                        props[col] = props[col].astype(np.uint64)
                else:
                    if mn > np.iinfo(np.int8).min and mx < np.iinfo(np.int8).max:
                        props[col] = props[col].astype(np.int8)
                    elif mn > np.iinfo(np.int16).min and mx < np.iinfo(np.int16).max:
                        props[col] = props[col].astype(np.int16)
                    elif mn > np.iinfo(np.int32).min and mx < np.iinfo(np.int32).max:
                        props[col] = props[col].astype(np.int32)
                    elif mn > np.iinfo(np.int64).min and mx < np.iinfo(np.int64).max:
                        props[col] = props[col].astype(np.int64)    
            
            # Make float datatypes 32 bit
            else:
                props[col] = props[col].astype(np.float32)
            
            # Print new column type
            print("dtype after: ",props[col].dtype)
            print("******************************")
    
    # Print final result
    print("___MEMORY USAGE AFTER COMPLETION:___")
    mem_usg = props.memory_usage().sum() / 1024**2 
    print("Memory usage is: ",mem_usg," MB")
    print("This is ",100*mem_usg/start_mem_usg,"% of the initial size")
    return props, NAlist

# %%
#python #python/pandas
trans_df = pd.read_csv(os.path.join(input_dir, 'historical_transactions.csv'))
train_df = pd.read_csv(os.path.join(input_dir, 'train.csv'))
new_trans_df = pd.read_csv(os.path.join(input_dir, 'new_merchant_transactions.csv'))
test_df = pd.read_csv(os.path.join(input_dir, 'test.csv'))

trans_df, _ = reduce_mem_usage(trans_df, fillna=True, fillval=-999)
test_df, _ = reduce_mem_usage(test_df, fillna=True, fillval=-999)
train_df, _ = reduce_mem_usage(train_df, fillna=False, fillval=-999)
new_trans_df, _ = reduce_mem_usage(new_trans_df, fillna=True, fillval=-999)
# Out:
# Memory usage of properties dataframe is : 3109.5357055664062  MB
# ******************************
# Column:  city_id
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  installments
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  merchant_category_id
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  month_lag
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  purchase_amount
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  category_2
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  state_id
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  subsector_id
# dtype before:  int64
# dtype after:  int8
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1721.3501567840576  MB
# This is  55.357143952476704 % of the initial size
# Memory usage of properties dataframe is : 4.715919494628906  MB
# ******************************
# Column:  feature_1
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_2
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_3
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  2.2401018142700195  MB
# This is  47.50084934277047 % of the initial size
# Memory usage of properties dataframe is : 9.24310302734375  MB
# ******************************
# Column:  feature_1
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_2
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_3
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  target
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  4.4290266036987305  MB
# This is  47.917096570236204 % of the initial size
# Memory usage of properties dataframe is : 209.67440795898438  MB
# ******************************
# Column:  city_id
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  installments
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  merchant_category_id
# dtype before:  int64
# dtype after:  int16
# ******************************
# ******************************
# Column:  month_lag
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  purchase_amount
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  category_2
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  state_id
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  subsector_id
# dtype before:  int64
# dtype after:  int8
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  116.06979560852051  MB
# This is  55.35715910127935 % of the initial size

# %%
print('[*]train_df : ', train_df.shape)
print('[*]test_df : ', test_df.shape)
print('[*]trans_df : ', trans_df.shape)
print('[*]new_trans_df : ', new_trans_df.shape)
# Out:
# [*]train_df :  (201917, 6)
# [*]test_df :  (123623, 5)
# [*]trans_df :  (29112361, 14)
# [*]new_trans_df :  (1963031, 14)

# %% [markdown]
# # check card_id

# %%
trans_id = set(trans_df.card_id.unique())
new_trans_id = set(new_trans_df.card_id.unique())
train_id = set(train_df.card_id.unique())
test_id = set(test_df.card_id.unique())
print('trans_id : {}'.format(len(trans_id)))
print('new_trans_id : {}'.format(len(new_trans_id)))
print('train_id : {}'.format(len(train_id)))
print('test_id : {}'.format(len(test_id)))
# Out:
# trans_id : 325540
# new_trans_id : 290001
# train_id : 201917
# test_id : 123623

# %%
#100% data in trans_df
print('[*]train data in trans', 1 - len(train_id - trans_id)/len(train_id))
print('[*]test data in trans', 1 - len(test_id - trans_id)/len(test_id))
# Out:
# [*]train data in trans 1.0
# [*]test data in trans 1.0

# %%
#about 90% data in new_trans_df
print('[*]train data in new_trans', 1 - len(train_id - new_trans_id)/len(train_id))
print('[*]test data in new_trans', 1 - len(test_id - new_trans_id)/len(test_id))
# Out:
# [*]train data in new_trans 0.8913860645710862
# [*]test data in new_trans 0.8899233961317878

# %%
all_trans_df = pd.concat([trans_df, new_trans_df])
all_trans_df = pd.merge(all_trans_df, train_df, on=['card_id'], how='left')
del train_df, test_df, trans_df, new_trans_df
gc.collect()
# Out:
# 42

# %%
all_trans_df = all_trans_df[all_trans_df.target.notnull()]
all_trans_df, _ = reduce_mem_usage(all_trans_df)
print('[*]all_trans_df : ', all_trans_df.shape)
# Out:
# Memory usage of properties dataframe is : 1964.2994480133057  MB
# ******************************
# Column:  city_id
# dtype before:  int16
# dtype after:  int16
# ******************************
# ******************************
# Column:  installments
# dtype before:  int16
# dtype after:  int16
# ******************************
# ******************************
# Column:  merchant_category_id
# dtype before:  int16
# dtype after:  int16
# ******************************
# ******************************
# Column:  month_lag
# dtype before:  int16
# dtype after:  int8
# ******************************
# ******************************
# Column:  purchase_amount
# dtype before:  float32
# dtype after:  float32
# ******************************
# ******************************
# Column:  category_2
# dtype before:  uint8
# dtype after:  uint8
# ******************************
# ******************************
# Column:  state_id
# dtype before:  int8
# dtype after:  int8
# ******************************
# ******************************
# Column:  subsector_id
# dtype before:  int8
# dtype after:  int8
# ******************************
# ******************************
# Column:  feature_1
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_2
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  feature_3
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  target
# dtype before:  float32
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1560.4247951507568  MB
# This is  79.4392523364486 % of the initial size
# [*]all_trans_df :  (19249694, 19)

# %%
all_trans_df.head(3)
# Out:
#     authorized_flag          card_id  city_id category_1  installments  \
# 400               N  C_ID_5037ff576e      322          N             1
# 401               Y  C_ID_5037ff576e      138          N             1
# 402               Y  C_ID_5037ff576e      138          N             1
#
#     category_3  merchant_category_id      merchant_id  month_lag  \
# 400          B                   278  M_ID_b61c7d1be0         -3
# 401          B                   307  M_ID_fe69229f24         -4
# 402          B                   705  M_ID_efc106141c         -9
#
#      purchase_amount        purchase_date  category_2  state_id  subsector_id  \
# 400        -0.595260  2017-09-07 20:57:19           3        11            37
# 401         1.189469  2017-08-14 15:46:08           1        15            19
# 402        -0.640069  2017-03-05 14:57:51           1        15            33
#
#     first_active_month  feature_1  feature_2  feature_3    target
# 400            2017-01          5          1          1 -2.352713
# 401            2017-01          5          1          1 -2.352713
# 402            2017-01          5          1          1 -2.352713

# %%
all_trans_df['first_active_year'] = all_trans_df['first_active_month'].apply(lambda x: x[0:4])

# %%
fig = plt.figure(figsize=(20, 5))
plt.suptitle('target by first_active_year', fontsize=16)
plt.ylabel('target_mean')
all_trans_df.groupby(['first_active_year']).target.mean().plot(kind='bar',alpha=0.75, rot=-90)

# %%
fig = plt.figure(figsize=(20, 5))
plt.suptitle('size by first_active_year', fontsize=16)
plt.ylabel('size')
all_trans_df.groupby(['first_active_year']).size().plot(kind='bar',alpha=0.75, rot=-90)

# %% [markdown]
# use first_active_year<br/>
# features : [first_active_year]

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 5))
plt.suptitle('authorized_flag', fontsize=16)
all_trans_df.groupby(['authorized_flag']).size().plot(kind='bar', alpha=0.75, rot=-90, ax=axes[0])
axes[0].set_title('authorized_flag_count')
axes[0].set_ylabel('authorized_flag_count')
all_trans_df.groupby(['authorized_flag']).target.mean().plot(kind='bar', alpha=0.75, rot=-270, ax=axes[1])
axes[1].set_title('authorized_flag_and_target')
axes[1].set_ylabel('target_mean')
# Out:
# Text(0, 0.5, 'target_mean')

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 10))
fig.suptitle('value_counts by authorized_flag', fontsize=20)
axes[0][0].set_title('category_1')
all_trans_df.groupby(['authorized_flag']).category_1.value_counts().plot(kind='bar', ax=axes[0][0])
axes[0][1].set_title('category_2')
all_trans_df.groupby(['authorized_flag']).category_2.value_counts().plot(kind='bar', ax=axes[0][1])
axes[0][2].set_title('category_3')
all_trans_df.groupby(['authorized_flag']).category_3.value_counts().plot(kind='bar', ax=axes[0][2])
axes[1][2].set_title('feature_1')
all_trans_df.groupby(['authorized_flag']).feature_1.value_counts().plot(kind='bar', ax=axes[1][0])
axes[1][2].set_title('feature_2')
all_trans_df.groupby(['authorized_flag']).feature_2.value_counts().plot(kind='bar', ax=axes[1][1])
axes[1][2].set_title('feature_3')
all_trans_df.groupby(['authorized_flag']).feature_3.value_counts().plot(kind='bar', ax=axes[1][2])

# %%
fig = plt.figure(figsize=(20, 5))
plt.suptitle('authorized_flag by year', fontsize=20)
sns.countplot(x='first_active_year', hue='authorized_flag', data=all_trans_df)

# %%
test_df = all_trans_df.groupby(['first_active_year']).authorized_flag.value_counts().unstack()
test_df['percentage'] = test_df['Y'] / (test_df['Y']+test_df['N']) * 100
fig = plt.figure(figsize=(20, 5))
fig.suptitle('authorized_flag Y percentage by first_active_year', fontsize=20)
sns.lineplot(x=test_df.index, y='percentage', data=test_df, marker="o")

# %% [markdown]
# use authorized_flag<br/>
# features : [first_active_year, authorized_flag]

# %% [markdown]
# # purchase_amount

# %%
fig, axes = plt.subplots(2, 1, figsize=(20, 10))
fig.suptitle('purchase_amount', fontsize=20)
axes[0].set_title('purchase_amount', fontsize=15)
sns.distplot(all_trans_df.purchase_amount, ax=axes[0])
axes[1].set_title('purchase_amount_log', fontsize=15)
sns.distplot(np.log1p(all_trans_df.purchase_amount), ax=axes[1])

# %%
all_trans_df['purchase_amount_log'] = np.log1p(all_trans_df['purchase_amount'])

# %%
fig, axes = plt.subplots(2, 1, figsize=(20, 10))
plt.suptitle('purchase_amount_sum', fontsize=16)
all_trans_df.groupby(['first_active_year']).aggregate({'purchase_amount':'sum'}).plot(kind='bar', ax=axes[0])
all_trans_df.groupby(['first_active_year']).aggregate({'purchase_amount_log':'sum'}).plot(kind='bar', ax=axes[1])

# %%
test_df = all_trans_df.groupby(['card_id']).aggregate({'purchase_amount':['mean', 'sum'],
                                                       'purchase_amount_log': ['mean', 'sum'],
                                                       'target':'mean',})

# %%
test_df.head(3)
# Out:
#                 purchase_amount_log             purchase_amount             \
#                                mean         sum            mean        sum
# card_id
# C_ID_00007093c1           -0.832803 -125.753250       -0.517706 -78.173561
# C_ID_0001506ef0           -0.992008  -67.456535       -0.530136 -36.049232
# C_ID_000183fdda           -0.874372 -135.527695       -0.486637 -75.428719
#
#                    target
#                      mean
# card_id
# C_ID_00007093c1  0.134077
# C_ID_0001506ef0  0.884295
# C_ID_000183fdda -0.264433

# %%
test_df.columns = ['purchase_amount_log_mean', 'purchase_amount_log_sum',
                   'purchase_amount_mean', 'purchase_amount_sum',
                   'target']

test_df['purchase_amount_sum_log'] = np.log1p(test_df['purchase_amount_sum'])
test_df['purchase_amount_mean_log'] = np.log1p(test_df['purchase_amount_mean'])
idx = test_df.purchase_amount_sum < 600000

fig, axes = plt.subplots(6, 1, figsize=(20, 18), constrained_layout=True)
axes[0].set_xlabel('purchase_amount_sum')
axes[0].set_ylabel('target')
axes[0].set_title('X=purchase_amount_sum, Y=target', fontsize=12)
sns.scatterplot(x='purchase_amount_sum', y='target', data=test_df[idx], marker="+", ax=axes[0])

axes[1].set_xlabel('purchase_amount_sum_log')
axes[1].set_ylabel('target')
axes[1].set_title('X=purchase_amount_sum_log, Y=target', fontsize=12)
sns.scatterplot(x='purchase_amount_sum_log', y='target', data=test_df[idx], marker="+", ax=axes[1])

axes[2].set_xlabel('purchase_amount_log_sum')
axes[2].set_ylabel('target')
axes[2].set_title('X=purchase_amount_log_sum, Y=target', fontsize=12)
sns.scatterplot(x='purchase_amount_log_sum', y='target', data=test_df[idx], marker="+", ax=axes[2])

axes[3].set_xlabel('purchase_amount_mean')
axes[3].set_ylabel('target')
axes[3].set_title('X=purchase_amount_mean, Y=target', fontsize=12)
sns.scatterplot(x='purchase_amount_mean', y='target', data=test_df[idx], marker="+", ax=axes[3])

axes[4].set_xlabel('purchase_amount_mean_log')
axes[4].set_ylabel('target')
axes[4].set_title('X=purchase_amount_mean_log, Y=target', fontsize=12)
sns.scatterplot(x='purchase_amount_mean_log', y='target', data=test_df[idx], marker="+", ax=axes[4])

axes[5].set_xlabel('purchase_amount_log_mean')
axes[5].set_ylabel('target')
axes[5].set_title('X=purchase_amount_log_mean, Y=target', fontsize=12)
sns.scatterplot(x='purchase_amount_log_mean', y='target', data=test_df[idx], marker="+", ax=axes[5])
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in log1p
#   """

# %% [markdown]
# use purchase_amount_sum, purchase_amount_sum_log, purchase_amount_mean, purchase_amount_mean_log<br/>
# features : [first_active_year, authorized_flag, purchase_amount_sum, purchase_amount_sum_log, purchase_amount_mean, purchase_amount_mean_log]

# %% [markdown]
# # card_id

# %% [markdown]
# # purchase_interval

# %%
all_trans_df.purchase_date = pd.to_datetime(all_trans_df.purchase_date,
                                            format='%Y-%m-%d %H:%M:%S')
all_trans_df.first_active_month = pd.to_datetime(all_trans_df.first_active_month, 
                                                 format='%Y-%m')
all_trans_df['purchase_interval'] = all_trans_df.purchase_date - all_trans_df.first_active_month 
all_trans_df['purchase_interval'] = all_trans_df.purchase_interval.apply(lambda x: x.days)

# %%
fig = plt.figure(figsize=(20, 5))
plt.suptitle('X:purchase_interval')
sns.distplot(all_trans_df.purchase_interval, bins=500)

# %%
test_df = all_trans_df.groupby(['card_id']).aggregate({'purchase_interval': ['mean', 'sum'],
                                                       'target': 'mean'})

# %%
test_df.head(3)
# Out:
#                 purchase_interval           target
#                              mean    sum      mean
# card_id
# C_ID_00007093c1        200.900662  30336  0.134077
# C_ID_0001506ef0        448.294118  30484  0.884295
# C_ID_000183fdda         98.438710  15258 -0.264433

# %%
#target ~ purchase_date - first_active
test_df = all_trans_df.groupby(['card_id']).aggregate({'purchase_interval': ['mean', 'sum'],
                                                       'target': 'mean'})
test_df.columns = ['purchase_interval_mean', 'purchase_interval_sum', 'target']

# %%
fig, axes = plt.subplots(2, 1, figsize=(20, 10))
fig.suptitle('X=purchase_interval, Y=target', fontsize=20)
axes[0].set_title('purchase_interval_mean')
sns.scatterplot(x=test_df.purchase_interval_mean, y=test_df.target, marker='+', ax=axes[0])
axes[1].set_title('purchase_interval_sum')
sns.scatterplot(x=test_df.purchase_interval_sum, y=test_df.target, marker='+', ax=axes[1])

# %%
fig = plt.figure(figsize=(20, 5))
all_trans_df.groupby(['first_active_year']).purchase_interval.std().plot(kind='bar', alpha=0.75, rot=-90)
plt.suptitle('X:first_active_year Y:purchase_interval', fontsize=20)
# Out:
# Text(0.5, 0.98, 'X:first_active_year Y:purchase_interval')

# %% [markdown]
# # month_lag

# %%
test_df = all_trans_df.groupby(['month_lag']).aggregate({'target': 'mean'}).reset_index()
plt.figure(figsize=(20, 5))
plt.title('X:month_lag, y:target_mean')
plt.xlabel('month_lag')
plt.ylabel('target_mean')
sns.barplot(x='month_lag', y='target', data=test_df)

# %%
fig = plt.figure(figsize=(20, 5))
all_trans_df.groupby(['first_active_year']).month_lag.std().plot(kind='bar', alpha=0.75, rot=-90)
plt.suptitle('X:first_active_year Y:month_lag_mean', fontsize=20)
# Out:
# Text(0.5, 0.98, 'X:first_active_year Y:month_lag_mean')

# %% [markdown]
# use purchase_interval, purchase_interval_cut<br/>
# features : [first_active_year, authorized_flag, <br/>
#             purchase_amount_sum, purchase_amount_sum_log, purchase_amount_mean, purchase_amount_mean_log, <br/>
#             purchase_interval_sum, purchase_interval_mean, purchase_interval_cut]

# %% [markdown]
# # Category_1, Category_2, Category_3

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5))
fig.suptitle('Category and target_mean')
all_trans_df.groupby(['category_1']).target.mean().plot(kind='bar',alpha=0.75, rot=-90, ax=axes[0])
all_trans_df.groupby(['category_2']).target.mean().plot(kind='bar',alpha=0.75, rot=-90, ax=axes[1])
all_trans_df.groupby(['category_3']).target.mean().plot(kind='bar',alpha=0.75, rot=-90, ax=axes[2])

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5))
fig.suptitle('Category_count and first_active_year')
sns.countplot(x='first_active_year', hue='category_1', data=all_trans_df, ax=axes[0])
sns.countplot(x='first_active_year', hue='category_2', data=all_trans_df, ax=axes[1])
sns.countplot(x='first_active_year', hue='category_3', data=all_trans_df, ax=axes[2])

# %%
all_trans_df['category_1_label'] = all_trans_df['category_1'].map({'N': 0, 'Y': 1})
all_trans_df['category_2_label'] = all_trans_df['category_2'].apply(lambda x: int(x))
all_trans_df['category_3_label'] = all_trans_df['category_3'].map({'A': 0, 'B': 1, 'C': 2})

# %%
test_df = all_trans_df.groupby(['card_id']).aggregate({'category_1_label': ['sum', 'mean'],
                                                       'category_2_label': ['sum', 'mean'], 
                                                       'category_3_label': ['sum', 'mean'],
                                                       'target':'mean'})
tmp_col = []
for col in test_df.columns:
    tmp_col.append('{}_{}'.format(col[0], col[1]))
test_df.columns = tmp_col

# %%
test_df.columns = tmp_col

# %%
sns.heatmap(test_df.corr())

# %%
idx = 0
fig, axes = plt.subplots(6, 1, figsize=(20, 25), constrained_layout=True)
for col in test_df.columns:
    if col=='target_mean':
        continue
    sns.scatterplot(x=col, y='target_mean',
                    ax=axes[idx], data=test_df)
    axes[idx].set_title('X:{} Y:{}'.format(col, 'target_mean'))
    idx += 1

# %% [markdown]
# use category_1_label_sum, category_2_label_sum, category_3_label_sum<br/>
# features : [first_active_year, authorized_flag, <br/>
#             purchase_amount_sum, purchase_amount_sum_log, purchase_amount_mean, purchase_amount_mean_log, <br/>
#             purchase_interval_sum, purchase_interval_mean, purchase_interval_cut, <br/>
#             category_1_label_sum, category_2_label_sum, category_3_label_sum]

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5))
axes[0].set_title('1 and 2')
sns.countplot(x='category_1_label', hue='category_2_label', data=all_trans_df, ax=axes[0])
axes[1].set_title('2 and 3')
sns.countplot(x='category_2_label', hue='category_3_label', data=all_trans_df, ax=axes[1])
axes[2].set_title('1 and 3')
sns.countplot(x='category_1_label', hue='category_3_label', data=all_trans_df, ax=axes[2])

# %% [markdown]
# # installments

# %%
fig, axes = plt.subplots(3, 1, figsize=(20, 10))
fig.suptitle('Installments', fontsize=16)
axes[0].set_title('Installments_countplot')
sns.countplot(x='installments', data=all_trans_df, ax=axes[0])
axes[1].set_title('Installments_Purchase_amount_mean')
all_trans_df.groupby(['installments']).purchase_amount.mean().plot(kind='bar', alpha=0.75, ax=axes[1])
axes[2].set_title('Installments_target_mean')
all_trans_df.groupby(['installments']).target.mean().plot(kind='bar', alpha=0.75, ax=axes[2])

# %%
test_df = all_trans_df.groupby(['card_id']).aggregate({'installments': 'mean'})
fig = plt.figure(figsize=(20, 5))
fig.suptitle('installments_mean by card_id', fontsize=20)
sns.distplot(test_df.installments, bins=500)

# %%
fig = plt.figure(figsize=(20, 5))
fig.suptitle('Installments_mean by card_id and target_mean', fontsize=20)
test_df = all_trans_df.groupby(['card_id']).aggregate({'installments':'mean', 'target':'mean'})
sns.scatterplot(x='installments', y='target', data=test_df)

# %%
fig = plt.figure(figsize=(20, 5))
fig.suptitle('Installments_sum by card_id and target_mean', fontsize=20)
test_df = all_trans_df.groupby(['card_id']).aggregate({'installments':'sum', 'target':'mean'})
sns.scatterplot(x='installments', y='target', data=test_df)

# %% [markdown]
# use installments_mean, installments_sum<br/>
# features : [first_active_year, authorized_flag, <br/>
#             purchase_amount_sum, purchase_amount_sum_log,<br/>
#             purchase_amount_mean, purchase_amount_mean_log, <br/>
#             purchase_interval_sum, purchase_interval_mean, purchase_interval_cut, <br/>
#             category_1_label_sum, category_2_label_sum, category_3_label_sum, <br/>
#             installments_mean, installments_sum]

# %%
print('[*]category_3 (installments == -1) : {}'.format(all_trans_df.query('installments == -1')['category_3'].unique()))
print('[*]installments (category_3 == null) : {}'.format(all_trans_df[all_trans_df['category_3'].isnull()]['installments'].unique()))
#[cetogory_3 == None] <-> [installments == -1]
#catogory_3(None) and installments(-1) -> cancle purchase
# Out:
# [*]category_3 (installments == -1) : [nan]
# [*]installments (category_3 == null) : [-1]

# %%
all_trans_df[all_trans_df['installments']==999]
# Out:
#          authorized_flag          card_id  city_id category_1  installments  \
# 227606                 N  C_ID_8b04d4734e      210          N           999
# 466436                 N  C_ID_7670e569a0      333          N           999
# 759501                 N  C_ID_652976a4bb       19          N           999
# 1182532                N  C_ID_24fb1a2959      331          N           999
# 1221217                N  C_ID_ba84d050f5       19          N           999
# 1368209                N  C_ID_5b6278eb25       69          N           999
# 1767608                N  C_ID_9cea123f42      181          N           999
# 3128460                N  C_ID_c379d12476       42          N           999
# 3323423                N  C_ID_ef6709bf85      190          N           999
# 3440873                N  C_ID_c9d2343ab0      117          N           999
# 4024235                N  C_ID_105ae2e0d1      125          N           999
# 4024281                N  C_ID_105ae2e0d1      125          N           999
# 4574655                N  C_ID_a58276801c       19          N           999
# 4631681                N  C_ID_eefb4d9fcc      302          N           999
# 5273962                N  C_ID_f46fcb0feb       17          N           999
# 5850302                N  C_ID_478cd7cc91       69          N           999
# 6222185                N  C_ID_dbd5f93456      158          N           999
# 6781702                N  C_ID_7c97a8d5c3      200          N           999
# 7257431                N  C_ID_262dee69d3       33          N           999
# 7456746                N  C_ID_4db57b6fc7       20          N           999
# 8010607                N  C_ID_76859ed625       69          N           999
# 8010833                N  C_ID_76859ed625       69          N           999
# 9218236                N  C_ID_419d577b92       17          N           999
# 9634046                N  C_ID_dbe526bf85      344          N           999
# 9958645                Y  C_ID_875f80a30c      340          N           999
# 10803783               N  C_ID_46c6c89d0b      310          N           999
# 10941824               N  C_ID_5dd4d58ae9       -1          N           999
# 11048906               N  C_ID_f28ef285a9       69          N           999
# 11925034               N  C_ID_fbce6b2487      140          N           999
# 11961500               N  C_ID_869ab2b81f      170          N           999
# ...                  ...              ...      ...        ...           ...
# 24919834               N  C_ID_867295e132      138          N           999
# 24940983               N  C_ID_5b2a2b3ded      179          N           999
# 25056443               N  C_ID_7de71b3c45      212          N           999
# 25336204               N  C_ID_a8f3b858c5      147          N           999
# 25367707               N  C_ID_289ca338ac      104          N           999
# 25760387               N  C_ID_5348adf7c6       69          N           999
# 26064583               N  C_ID_b92da701aa      331          N           999
# 26194769               N  C_ID_d1e2f124ee       -1          N           999
# 26243998               N  C_ID_b75d8161ad      302          N           999
# 26493409               N  C_ID_9befd83ccc       28          N           999
# 26530422               N  C_ID_4d0a87d69e      344          N           999
# 26770977               N  C_ID_b56b679112      320          N           999
# 26973702               N  C_ID_41f4a5ebc5       69          N           999
# 27078432               N  C_ID_0e00a3c5e2      333          N           999
# 27138713               N  C_ID_a3c2a00954        6          N           999
# 27163381               N  C_ID_908f2207d2       79          N           999
# 27831437               N  C_ID_fe57f79f61      149          N           999
# 27871554               N  C_ID_6ac6dd5186       69          N           999
# 27935666               N  C_ID_f4469d2e92      334          N           999
# 28020816               N  C_ID_93fb16467d      210          N           999
# 28041194               N  C_ID_ae7caea729      100          N           999
# 28182192               N  C_ID_c8cb6bd652       17          N           999
# 28771480               N  C_ID_b3302b05e1      137          N           999
# 28779995               N  C_ID_a2d38bdf60      169          N           999
# 28814708               N  C_ID_d60c31581e      179          N           999
# 28880387               N  C_ID_5f57070e0c      301          N           999
# 28978222               N  C_ID_730f3751de      117          N           999
# 29012755               N  C_ID_2c1f702b6a      330          N           999
# 29018065               Y  C_ID_6715eccea8      174          N           999
# 29743748               Y  C_ID_726ae3c2bc      174          N           999
#
#          category_3  merchant_category_id      merchant_id  month_lag  \
# 227606            C                   806  M_ID_0155450c84        -11
# 466436            C                   813  M_ID_c9526f2dd3        -10
# 759501            C                   356  M_ID_2570628257         -8
# 1182532           C                   117  M_ID_67a62f2671         -3
# 1221217           C                   884  M_ID_8e7a785122         -8
# 1368209           C                   683  M_ID_f86439cec0         -6
# 1767608           C                    90  M_ID_596749cc5a          0
# 3128460           C                   419  M_ID_eaddfae8a1         -8
# 3323423           C                   225  M_ID_5cce2da9c8         -2
# 3440873           C                   422  M_ID_5958549349        -10
# 4024235           C                   792  M_ID_43d0f0f4dc          0
# 4024281           C                   792  M_ID_43d0f0f4dc          0
# 4574655           C                    87  M_ID_d0146c836a         -2
# 4631681           C                    68  M_ID_c24ebf2f81         -2
# 5273962           C                   422  M_ID_6d999339f8        -12
# 5850302           C                    87  M_ID_c700c6f928          0
# 6222185           C                   222  M_ID_cd7124f247         -5
# 6781702           C                   605  M_ID_91ba5dc816         -4
# 7257431           C                   884  M_ID_d4157cc958         -4
# 7456746           C                   840  M_ID_0dacb1258d         -4
# 8010607           C                    34  M_ID_c9714065ed         -8
# 8010833           C                    34  M_ID_c9714065ed         -8
# 9218236           C                   367  M_ID_6aa09cb59c         -5
# 9634046           C                    45  M_ID_b7459adc65         -2
# 9958645           C                   840  M_ID_995feeec61         -3
# 10803783          C                   222  M_ID_6400ce126a         -5
# 10941824          C                    34  M_ID_8da66c4d11         -5
# 27163381                 0                 1               2.0
# 27831437                 0                 5               2.0
# 27871554                 0                 1               2.0
# 27935666                 0                 5               2.0
# 28020816                 0                 1               2.0
# 28041194                 0                 1               2.0
# 28182192                 0                 4               2.0
# 28771480                 0                 3               2.0
# 28779995                 0                 5               2.0
# 28814708                 0                25               2.0
# 28880387                 0                 3               2.0
# 28978222                 0                 1               2.0
# 29012755                 0                 3               2.0
# 29018065                 0                 1               2.0
# 29743748                 0                 1               2.0
#
# [107 rows x 25 columns]

# %% [markdown]
# # city_id and merchant_category_id

# %%
fig = plt.figure(figsize=(20, 5))
all_trans_df.groupby(['city_id']).size().plot(kind='bar')

# %%
fig = plt.figure(figsize=(20, 5))
fig.suptitle('city_id and target_mean', fontsize=20)
test_df = all_trans_df.groupby(['city_id']).target.mean().reset_index().sort_values(by=['target'])
sns.barplot(x='city_id', y='target', data=test_df, order=test_df.city_id)

# %%
test_df = all_trans_df.groupby(['city_id']).size().reset_index()
test_df.columns = ['city_id', 'city_id_cnt']
test_df_2 = all_trans_df.groupby(['city_id']).target.mean().reset_index()
test_df = pd.merge(test_df, test_df_2, on=['city_id'], how='left')

# %%
fig = plt.figure(figsize=(20, 5))
fig.suptitle('X:city_id_cnt, Y:target_mean', fontsize=20)
sns.scatterplot(x='city_id_cnt', y='target', data=test_df)

# %%
fig = plt.figure(figsize=(20, 5))
all_trans_df.groupby(['merchant_category_id']).size().plot(kind='bar')

# %%
fig = plt.figure(figsize=(20, 5))
fig.suptitle('merchant_category_id and target_mean', fontsize=20)
test_df = all_trans_df.groupby(['merchant_category_id']).target.mean().reset_index().sort_values(by=['target'])
sns.barplot(x='merchant_category_id', y='target', data=test_df, order=test_df.merchant_category_id)

# %%
test_df = all_trans_df.groupby(['merchant_category_id']).size().reset_index()
test_df.columns = ['merchant_category_id', 'merchant_category_id_cnt']
test_df_2 = all_trans_df.groupby(['merchant_category_id']).target.mean().reset_index()
test_df = pd.merge(test_df, test_df_2, on=['merchant_category_id'], how='left')

# %%
fig = plt.figure(figsize=(20, 5))
fig.suptitle('X:merchant_category_id_cnt, Y:target_mean', fontsize=20)
sns.scatterplot(x='merchant_category_id_cnt', y='target', data=test_df)

# %%
fig = plt.figure(figsize=(20, 5))
all_trans_df.groupby(['subsector_id']).size().plot(kind='bar')

# %%
fig = plt.figure(figsize=(20, 5))
fig.suptitle('subsector_id and target_mean', fontsize=20)
test_df = all_trans_df.groupby(['subsector_id']).target.mean().reset_index().sort_values(by=['target'])
sns.barplot(x='subsector_id', y='target', data=test_df, order=test_df.subsector_id)

# %%
test_df = all_trans_df.groupby(['subsector_id']).size().reset_index()
test_df.columns = ['subsector_id', 'subsector_id_cnt']
test_df_2 = all_trans_df.groupby(['subsector_id']).target.mean().reset_index()
test_df = pd.merge(test_df, test_df_2, on=['subsector_id'], how='left')

# %%
fig = plt.figure(figsize=(20, 5))
fig.suptitle('X:subsector_id_cnt, Y:target_mean', fontsize=20)
sns.scatterplot(x='subsector_id_cnt', y='target', data=test_df)
